# %%
# %matplotlib inline
import matplotlib.pylab as pylab
pylab.rcParams['figure.figsize'] = 16, 12
import matplotlib.pyplot as plt
import numpy as np

import lasio
from las_conv import *

las_file = 'D:\\Data\\PAYS\\project12\\Logs\\F-O1.las'
l = lasio.read(las_file)

# %%
plt.plot(l["DT"], l["DEPT"])
plt.plot(l["DTm"], l["DEPT"], color='r')

# %%
# l.add_curve("DTm", l_dt_muSm)

# %%
with open(output_file, mode='w') as f:
    l.write(f)
